# %%
def adobe(path_output,date_actuelle):
        from selenium import webdriver
        from selenium.webdriver.common.by import By
        from selenium.webdriver.support import expected_conditions as EC
        from selenium.webdriver.support.ui import WebDriverWait
        import time
        import random
        
        # Initialisation du navigateur Chrome
        driver = webdriver.Chrome()
        driver.maximize_window()
        # Ouvrir une page web
        driver.get("https://new.express.adobe.com/tools/animate-from-audio?%24web_only=true&_branch_match_id=1411720928014136716&_branch_referrer=H4sIAAAAAAAAA8soKSkottLXT0zJT0otLkgsyi7ILy7RLU9N0kssKNDLyczL1k%2FVDytzyy0KLPEw9UiyrytKTUstKsrMS49PKsovL04tsnXOKMrPTQUA1wEtoEsAAAA%3D")

        temps_attente = random.uniform(3, 7)
        time.sleep(10)

        # Wait until the cookie banner button is clickable
        cookie = driver.find_element(By.XPATH, "/html/body/div[4]/div[2]/div[1]/div[1]/div/div[2]/div/button[3]")
        cookie.click()

        temps_attente = random.uniform(5, 9)
        time.sleep(temps_attente)

        # Connexion 
        connexion = driver.find_element(By.XPATH, "/html/body/div[3]/div/header/nav/div/ul/li[1]/div/ul/li/div/ul/li[3]/div/ul/li[1]/div/button/span")
        connexion.click()

        time.sleep(50)

        # adresse_emal

        element = driver.find_element(By.XPATH, '/html/body/x-app//x-quick-action-tools-view')
        element.click()
        
        time.sleep(100)

        image = driver.find_element(By.CSS_SELECTOR, 'div.qa-thumbnail-grid div.qa-thumbnail:nth-child(3)')
        image.click()  
        
        
        temps_attente = random.uniform(1, 4)
        time.sleep(10)

        
        taille_perso = driver.find_element(By.XPATH,"/html/body/x-app//x-quick-action-tools-view//quick-action-component//qa-app-root/qa-app/qa-animate-from-audio-editor//qa-workspace/div[5]/sp-tabs/sp-tab-panel[1]/qa-animate-from-audio-puppets-panel//div/qa-animate-from-audio-thumbnail-grid//qa-thumbnail-grid//div/div/qa-thumbnail[265]//button")
        driver.execute_script("""
        arguments[0].value = arguments[1]; 
        arguments[0].dispatchEvent(new Event('input')); 
        arguments[0].dispatchEvent(new Event('change'));
    """, taille_perso, 1.5)
        updated_value = taille_perso.get_attribute("value")
        print(f"Nouvelle valeur du slider : {updated_value}")

        temps_attente = random.uniform(1, 4)
        time.sleep(temps_attente)

        choisir_arriere_plan = driver.find_element(By.XPATH,"/html/body/x-app//x-quick-action-tools-view//quick-action-component//qa-app-root/qa-app/qa-animate-from-audio-editor//qa-workspace/div[5]/sp-tabs/sp-tab[2]//label")
        choisir_arriere_plan.click()

        temps_attente = random.uniform(1, 4)
        time.sleep(temps_attente)

        transparent = driver.find_element(By.XPATH,"/html/body/x-app//x-quick-action-tools-view//quick-action-component//qa-app-root/qa-app/qa-animate-from-audio-editor//qa-workspace/div[5]/sp-tabs/sp-tab-panel[2]/qa-animate-from-audio-backgrounds-panel//div/qa-animate-from-audio-thumbnail-grid//qa-thumbnail-grid//div/div[3]/qa-thumbnail[1]//button")
        transparent.click()
        
        temps_attente = random.uniform(1, 4)
        time.sleep(temps_attente)

        fichier = driver.find_element(By.XPATH,"/html/body/x-app//x-quick-action-tools-view//quick-action-component//qa-app-root/qa-app/qa-animate-from-audio-editor//qa-workspace/section/div/div/div[2]/span/qa-file-upload//div/div/span/div/sp-link/p")
        fichier.send_keys('/chemin/vers/ton/fichier.ext')

        temps_attente = random.uniform(1, 4)
        time.sleep(temps_attente)


        telecharger=driver.find_element(By.XPATH,"")
        telecharger.click()

        temps_attente = random.uniform(1, 4)
        time.sleep(temps_attente)

        driver.close()

adobe("outputs/",None)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[8], line 85
#      81         time.sleep(temps_attente)
#      83         driver.close()
# ---> 85 adobe("outputs/",None)
#
# Cell In[8], line 33, in adobe(path_output, date_actuelle)
#      29 time.sleep(100)
#      31 # adresse_emal
# ---> 33 element = driver.find_element(By.XPATH, '/html/body/x-app//x-quick-action-tools-view//quick-action-component//qa-app-root/qa-app/qa-animate-from-audio-editor//qa-workspace/div[5]/sp-tabs/sp-tab-panel[1]/qa-animate-from-audio-puppets-panel//div/qa-animate-from-audio-thumbnail-grid//qa-thumbnail-grid//div/div/qa-thumbnail[2]//button')
#      34 element.click()
#      36 time.sleep(100)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webdriver.py:888, in WebDriver.find_element(self, by, value)
# ...
